# %%
# !pip install langchain_ollama langchain_core streamlit
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: langchain_ollama in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (0.3.2)
# Requirement already satisfied: langchain_core in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (0.3.59)
# Collecting streamlit
#   Using cached streamlit-1.45.1-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: ollama<1,>=0.4.4 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from langchain_ollama) (0.4.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from langchain_core) (0.3.42)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from langchain_core) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from langchain_core) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from langchain_core) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from langchain_core) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from langchain_core) (4.13.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from langchain_core) (2.11.4)
# Requirement already satisfied: jsonpointer>=1.9 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain_core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain_core) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain_core) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain_core) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain_core) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain_core) (0.23.0)
# Requirement already satisfied: anyio in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (4.9.0)
# Requirement already satisfied: certifi in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (1.0.9)
# Requirement already satisfied: idna in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain_core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain_core) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain_core) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain_core) (2.4.0)
# Collecting altair<6,>=4.0 (from streamlit)
#   Using cached altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<6,>=4.0 (from streamlit)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting click<9,>=7.0 (from streamlit)
#   Using cached click-8.2.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy<3,>=1.23 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from streamlit) (2.2.5)
# Requirement already satisfied: pandas<3,>=1.4.0 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from streamlit) (2.2.3)
# Collecting pillow<12,>=7.1.0 (from streamlit)
#   Using cached pillow-11.2.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting protobuf<7,>=3.20 (from streamlit)
#   Using cached protobuf-6.31.0-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting pyarrow>=7.0 (from streamlit)
#   Using cached pyarrow-20.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Using cached watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Using cached GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Collecting narwhals>=1.14.2 (from altair<6,>=4.0->streamlit)
#   Using cached narwhals-1.39.0-py3-none-any.whl.metadata (11 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.24.0)
# Requirement already satisfied: six>=1.5 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (1.3.1)
# Using cached streamlit-1.45.1-py3-none-any.whl (9.9 MB)
# Using cached altair-5.5.0-py3-none-any.whl (731 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached click-8.2.0-py3-none-any.whl (102 kB)
# Using cached GitPython-3.1.44-py3-none-any.whl (207 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached pillow-11.2.1-cp311-cp311-manylinux_2_28_x86_64.whl (4.6 MB)
# Using cached protobuf-6.31.0-cp39-abi3-manylinux2014_x86_64.whl (320 kB)
# Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
# Using cached narwhals-1.39.0-py3-none-any.whl (339 kB)
# Using cached pyarrow-20.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (42.3 MB)
# Installing collected packages: watchdog, toml, smmap, pyarrow, protobuf, pillow, narwhals, click, cachetools, blinker, pydeck, gitdb, gitpython, altair, streamlit
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [streamlit]15 [streamlit]
# Successfully installed altair-5.5.0 blinker-1.9.0 cachetools-5.5.2 click-8.2.0 gitdb-4.0.12 gitpython-3.1.44 narwhals-1.39.0 pillow-11.2.1 protobuf-6.31.0 pyarrow-20.0.0 pydeck-0.9.1 smmap-5.0.2 streamlit-1.45.1 toml-0.10.2 watchdog-6.0.0

# %%
#!/usr/bin/env python3
import argparse
from langchain_ollama.chat_models import ChatOllama
from langchain_core.tools import tool
from langchain_core.messages import SystemMessage, HumanMessage
import requests

#
#   TOOL DEFINITION
#

@tool
def get_weather(latitude, longitude):
    """Fetches weather for given city"""

    response = requests.get(f"https://api.open-meteo.com/v1/forecast?latitude={latitude}&longitude={longitude}&current=temperature_2m,wind_speed_10m&hourly=temperature_2m,relative_humidity_2m,wind_speed_10m")
    data = response.json()
    return data['current']['temperature_2m']


#
#   RESPONSE FUNCTION
#

def get_response(prompt: str, use_function_calling: bool):
    messages = [
        SystemMessage("You are a helpful AI assistant. Answer concisely."),
        HumanMessage(prompt)
    ]

    if use_function_calling:
        model = ChatOllama(model="llama3.2").bind_tools([get_weather])
        # initial call
        res = model.invoke(messages)
        messages.append(res)

        # run any tool calls
        for tool_call in res.tool_calls:
            fn = tool_call["name"].lower()
            tool_fn = {"get_weather": get_weather}[fn]
            tool_msg = tool_fn.invoke(tool_call)
            messages.append(tool_msg)

        # final call with tool output
        res = model.invoke(messages)
        messages.append(res)
    else:
        model = ChatOllama(model="llama3.2")
        res = model.invoke(messages)
        messages.append(res)

    return res.content, messages

#
#   MAIN ENTRYPOINT
#

def main():
    parser = argparse.ArgumentParser(description="ChatOllama terminal client")
    parser.add_argument(
        "--prompt", "-p",
        type=str,
        required=True,
        help="The prompt to send to the assistant"
    )
    parser.add_argument(
        "--function-calling", "-f",
        action="store_true",
        help="Enable LangChain function calling (get_weather)"
    )
    args = parser.parse_args()

    response_text, chat_history = get_response(args.prompt, args.function_calling)

    print("\n=== Assistant response ===")
    print(response_text)

    print("\n=== Full chat messages ===")
    for msg in chat_history:
        role = getattr(msg, "role", msg.type)
        content = getattr(msg, "content", str(msg))
        print(f"[{role}] {content}")

if __name__ == "__main__":
    main()
# Out:
# usage: ipykernel_launcher.py [-h] --prompt PROMPT [--function-calling]
# ipykernel_launcher.py: error: the following arguments are required: --prompt/-p
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /home/maiconkevyn/PycharmProjects/chatbot-pysus/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3678: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
