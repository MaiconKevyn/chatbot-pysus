# %%
import pandas as pd

# %%
df = pd.read_csv("dados_sus3.csv")
df
# Out:
#                       data  pm10   so2   no2     o3    co
# 0      2014-01-01 00:00:00  84.4  0.65   NaN   9.10  0.025
# 1      2014-01-01 01:00:00  94.4  0.65   NaN  14.60  0.300
# 2      2014-01-01 02:00:00  75.5  0.65   NaN  11.70  0.025
# 3      2014-01-01 03:00:00  69.5  0.65   NaN   7.80  0.025
# 4      2014-01-01 04:00:00  52.0  0.65   NaN  11.80  0.025
# ...                    ...   ...   ...   ...    ...    ...
# 84903  2023-12-31 19:00:00   NaN  4.14  2.66  39.16  0.310
# 84904  2023-12-31 20:00:00   NaN  4.16  2.53  38.64  0.330
# 84905  2023-12-31 21:00:00   NaN  5.03  2.73  32.60  0.530
# 84906  2023-12-31 22:00:00   NaN  7.77  2.63  31.25  0.920
# 84907  2023-12-31 23:00:00   NaN  9.93  2.51  28.95  1.110
#
# [84908 rows x 6 columns]

# %%
df = pd.read_csv("dados_IBGE_modificados.csv", encoding="latin1", sep = ";")
df

#dados_sus3.csv
#IDH_municipios_RS.csv
#poluicao_do_ar_2014_2023.csv
# Out:
#        UF           Nome_UF  Região Geográfica Intermediária  \
# 0      11          Rondônia                             1102
# 1      11          Rondônia                             1102
# 2      11          Rondônia                             1102
# 3      11          Rondônia                             1102
# 4      11          Rondônia                             1102
# ...    ..               ...                              ...
# 10719  52             Goiás                             5202
# 10720  52             Goiás                             5206
# 10721  52             Goiás                             5205
# 10722  52             Goiás                             5205
# 10723  53  Distrito Federal                             5301
#
#       Nome Região Geográfica Intermediária  Região Geográfica Imediata  \
# 0                                Ji-Paraná                      110005
# 1                                Ji-Paraná                      110005
# ...
